# %% [markdown]
# # 6.2. Reading and Writing JSON Data

# %% [markdown]
# # Problem
# You want to read or write data encoded as JSON (JavaScript Object Notation).
#
# # Solution
# The `json` module provides an easy way to encode and decode data in JSON. The two
# main functions are `json.dumps()` and `json.loads()`, mirroring the interface used in
# other serialization libraries, such as `pickle`. Here is how you turn a Python data struc‐
# ture into JSON:
# ```python
# import json
#
# data = {
#     'name' : 'ACME',
#     'shares' : 100,
#     'price' : 542.23
# }
#
# json_str = json.dumps(data)
# ```
# Here is how you turn a JSON-encoded string back into a Python data structure:
# ```python
# data = json.loads(json_str)
# ```
# If you are working with files instead of strings, you can alternatively use `json.dump()`
# and `json.load()` to encode and decode JSON data. For example:
# ```python
# # Writing JSON data
# with open('data.json', 'w') as f:
#     json.dump(data, f)
#
# # Reading data back
# with open('data.json', 'r') as f:
#     data = json.load(f)
# ```

# %% [markdown]
# # Discussion
# JSON encoding supports the basic types of `None`, `bool`, `int`, `float`, and `str`, as well as
# lists, tuples, and dictionaries containing those types. For dictionaries, keys are assumed
# to be strings (any nonstring keys in a dictionary are converted to strings when encoding).
# To be compliant with the JSON specification, you should only encode Python lists and
# dictionaries. Moreover, in web applications, it is standard practice for the top-level ob‐
# ject to be a dictionary.
#
# The format of JSON encoding is almost identical to Python syntax except for a few
# minor changes. For instance, `True` is mapped to `true`, `False` is mapped to `false`, and
# `None` is mapped to `null`. Here is an example that shows what the encoding looks like:

# %%
import json
json.dumps(False)
# Out:
# 'false'

# %%
d = {'a': True,
     'b': 'Hello',
     'c': None}
json.dumps(d)
# Out:
# '{"b": "Hello", "c": null, "a": true}'

# %% [markdown]
# If you are trying to examine data you have decoded from JSON, it can often be hard to
# ascertain its structure simply by printing it out—especially if the data contains a deep
# level of nested structures or a lot of fields. To assist with this, consider using the `pprint()`
# function in the `pprint` module. This will alphabetize the keys and output a dictionary
# in a more sane way. Here is an example that illustrates how you would pretty print the
# results of a search on Twitter:

# %%
from urllib.request import urlopen
import json
u = urlopen('https://api.vk.com/method/friends.get?user_id=1&fields=domain,sex,bdate,nickname')
resp = json.loads(u.read().decode('utf-8'))
from pprint import pprint
pprint(resp)
# Out:
# {'response': [{'domain': 'alexandra',
#                'first_name': 'Александра',
#                'hidden': 1,
#                'last_name': 'Владимирова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 2,
#                'user_id': 2},
#               {'bdate': '18.11',
#                'domain': 'ilya',
#                'first_name': 'Илья',
#                'last_name': 'Перекопский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 5,
#                'user_id': 5},
#               {'domain': 'abacabadabacabaeabacabadabacaba',
#                'first_name': 'Николай',
#                'hidden': 1,
#                'last_name': 'Дуров',
#                'nickname': '',
#                'sex': 2,
#                'uid': 6,
#                'user_id': 6},
#               {'domain': 'id7',
#                'first_name': 'Алексей',
#                'hidden': 1,
#                'last_name': 'Кобылянский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 7,
#                'user_id': 7},
#               {'bdate': '28.12',
#                'domain': 'id12',
#                'first_name': 'Юлий',
#                'hidden': 1,
#                'last_name': 'Джумасултанов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 12,
#                'user_id': 12},
#               {'domain': 'id20',
#                'first_name': 'Илья',
#                'last_name': 'Турпиашвили',
#                'nickname': '',
#                'sex': 2,
#                'uid': 20,
#                'user_id': 20},
#               {'bdate': '23.7.1985',
#                'domain': 'mr',
#                'first_name': 'Михаил',
#                'last_name': 'Равдоникас',
#                'nickname': '',
#                'sex': 2,
#                'uid': 21,
#                'user_id': 21},
#               {'bdate': '31.1.1986',
#                'domain': 's.voronin',
#                'first_name': 'Семен',
#                'hidden': 1,
#                'last_name': 'Воронин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 22,
#                'user_id': 22},
#               {'bdate': '14.11',
#                'domain': 'ast',
#                'first_name': 'Андрей',
#                'hidden': 1,
#                'last_name': 'Столбовский',
#                'nickname': 'Upright',
#                'sex': 2,
#                'uid': 23,
#                'user_id': 23},
#               {'domain': 'id34',
#                'first_name': 'Татьяна',
#                'last_name': 'Плуталова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 34,
#                'user_id': 34},
#               {'bdate': '13.4.1984',
#                'domain': 'mikaza',
#                'first_name': 'Михаил',
#                'hidden': 1,
#                'last_name': 'Казекин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 37,
#                'user_id': 37},
#               {'bdate': '20.4',
#                'domain': 'id42',
#                'first_name': 'Сергей',
#                'hidden': 1,
#                'last_name': 'Маркин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 42,
#                'user_id': 42},
#               {'bdate': '28.1',
#                'domain': 'id45',
#                'first_name': 'Сергей',
#                'last_name': 'Виноградов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 45,
#                'user_id': 45},
#               {'bdate': '14.7.1984',
#                'domain': 'lesokhin',
#                'first_name': 'Андрей',
#                'hidden': 1,
#                'last_name': 'Лесохин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 46,
#                'user_id': 46},
#               {'bdate': '4.3',
#                'domain': 'ledkit',
#                'first_name': 'Екатерина',
#                'last_name': 'Фуртикова',
#                'nickname': 'ledkit',
#                'sex': 1,
#                'uid': 54,
#                'user_id': 54},
#               {'domain': 'vladimirov',
#                'first_name': 'Сергей',
#                'hidden': 1,
#                'last_name': 'Владимиров',
#                'nickname': '',
#                'sex': 2,
#                'uid': 57,
#                'user_id': 57},
#               {'bdate': '2.4.1985',
#                'domain': 'auntylorana',
#                'first_name': 'Анастасия',
#                'hidden': 1,
#                'last_name': 'Желудкова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 59,
#                'user_id': 59},
#               {'bdate': '9.3.1984',
#                'domain': 'konradt',
#                'first_name': 'Григорий',
#                'last_name': 'Конрадт',
#                'nickname': '',
#                'sex': 2,
#                'uid': 61,
#                'user_id': 61},
#               {'bdate': '4.1.1984',
#                'domain': 'id133',
#                'first_name': 'Николай',
#                'last_name': 'Харчев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 133,
#                'user_id': 133},
#               {'bdate': '5.6.1987',
#                'domain': 'usmanova',
#                'first_name': 'Ольга',
#                'last_name': 'Усманова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 169,
#                'user_id': 169},
#               {'bdate': '6.7.1984',
#                'domain': 'id173',
#                'first_name': 'Мария',
#                'hidden': 1,
#                'last_name': 'Чепурная',
#                'nickname': '',
#                'sex': 1,
#                'uid': 173,
#                'user_id': 173},
#               {'bdate': '23.11.1981',
#                'domain': 'mike',
#                'first_name': 'Михаил',
#                'last_name': 'Захаренков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 175,
#                'user_id': 175},
#               {'bdate': '22.3.1984',
#                'domain': 'id180',
#                'first_name': 'Владимир',
#                'last_name': 'Корнев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 180,
#                'user_id': 180},
#               {'bdate': '19.5',
#                'domain': 'nik.nik.andreev',
#                'first_name': 'Николай',
#                'hidden': 1,
#                'last_name': 'Андреев',
#                'nickname': 'Николаевич',
#                'sex': 2,
#                'uid': 182,
#                'user_id': 182},
#               {'bdate': '7.11',
#                'domain': 'grammakov',
#                'first_name': 'Денис',
#                'hidden': 1,
#                'last_name': 'Граммаков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 187,
#                'user_id': 187},
#               {'bdate': '4.5',
#                'domain': 'id190',
#                'first_name': 'Вадим',
#                'last_name': 'Колосов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 190,
#                'user_id': 190},
#               {'bdate': '4.10.1982',
#                'domain': 'ivand',
#                'first_name': 'Иван',
#                'last_name': 'Кораблев-Дайсон',
#                'nickname': '',
#                'sex': 2,
#                'uid': 193,
#                'user_id': 193},
#               {'bdate': '24.4.1974',
#                'domain': 'shtoong',
#                'first_name': 'Сергей',
#                'last_name': 'Гребнев',
#                'nickname': 'Леонидович',
#                'sex': 2,
#                'uid': 194,
#                'user_id': 194},
#               {'bdate': '3.5',
#                'domain': 'kirschner',
#                'first_name': 'Вальтер',
#                'last_name': 'Киршнер',
#                'nickname': '',
#                'sex': 2,
#                'uid': 198,
#                'user_id': 198},
#               {'domain': 'elenaparsons',
#                'first_name': 'Елена',
#                'hidden': 1,
#                'last_name': 'Парсонс',
#                'nickname': '',
#                'sex': 1,
#                'uid': 199,
#                'user_id': 199},
#               {'bdate': '3.10.1983',
#                'domain': 'id201',
#                'first_name': 'Игнатий',
#                'hidden': 1,
#                'last_name': 'Дьяков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 201,
#                'user_id': 201},
#               {'bdate': '3.10',
#                'domain': 'id230',
#                'first_name': 'Олеся',
#                'hidden': 1,
#                'last_name': 'Дигина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 230,
#                'user_id': 230},
#               {'bdate': '17.1.1983',
#                'domain': 'id231',
#                'first_name': 'Юрий',
#                'hidden': 1,
#                'last_name': 'Бычков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 231,
#                'user_id': 231},
#               {'domain': 'jul',
#                'first_name': 'Юлия',
#                'last_name': 'Глейм',
#                'nickname': '',
#                'sex': 1,
#                'uid': 234,
#                'user_id': 234},
#               {'bdate': '15.7.1985',
#                'domain': 'water',
#                'first_name': 'Сергей',
#                'last_name': 'Журавлёв',
#                'nickname': 'Александрович',
#                'sex': 2,
#                'uid': 237,
#                'user_id': 237},
#               {'bdate': '16.12.1989',
#                'domain': 'asya',
#                'first_name': 'Ася',
#                'last_name': 'Щёголь',
#                'nickname': '',
#                'sex': 1,
#                'uid': 254,
#                'user_id': 254},
#               {'bdate': '4.1.1982',
#                'domain': 'mrkam',
#                'first_name': 'Александр',
#                'hidden': 1,
#                'last_name': 'Кузнецов',
#                'nickname': 'КАМ',
#                'sex': 2,
#                'uid': 277,
#                'user_id': 277},
#               {'bdate': '20.3',
#                'domain': 'ivankondakov',
#                'first_name': 'Иван',
#                'last_name': 'Кондаков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 287,
#                'user_id': 287},
#               {'bdate': '28.11.1982',
#                'domain': 'outlab',
#                'first_name': 'Сергей',
#                'hidden': 1,
#                'last_name': 'Покровский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 288,
#                'user_id': 288},
#               {'bdate': '26.2.1988',
#                'domain': 'lesokhina',
#                'first_name': 'Дарья',
#                'hidden': 1,
#                'last_name': 'Лесохина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 316,
#                'user_id': 316},
#               {'bdate': '10.5',
#                'domain': 'id326',
#                'first_name': 'Екатерина',
#                'hidden': 1,
#                'last_name': 'Яроцкая',
#                'nickname': '',
#                'sex': 1,
#                'uid': 326,
#                'user_id': 326},
#               {'domain': 'polia',
#                'first_name': 'Полина',
#                'hidden': 1,
#                'last_name': 'Богуш',
#                'nickname': '',
#                'sex': 1,
#                'uid': 334,
#                'user_id': 334},
#               {'domain': 'web',
#                'first_name': 'Shmavon',
#                'hidden': 1,
#                'last_name': 'Gazanchyan',
#                'nickname': '',
#                'sex': 2,
#                'uid': 341,
#                'user_id': 341},
#               {'bdate': '19.10',
#                'domain': 'dari',
#                'first_name': 'Дарья',
#                'hidden': 1,
#                'last_name': 'Фролова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 345,
#                'user_id': 345},
#               {'bdate': '27.4.1983',
#                'domain': 'id358',
#                'first_name': 'Екатерина',
#                'hidden': 1,
#                'last_name': 'Фейн',
#                'nickname': '',
#                'sex': 1,
#                'uid': 358,
#                'user_id': 358
# },
#               {'bdate': '5.6.1987',
#                'domain': 'v.kirikov',
#                'first_name': 'Вадим',
#                'hidden': 1,
#                'last_name': 'Кириков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 366,
#                'user_id': 366},
#               {'domain': 'id369',
#                'first_name': 'Марина',
#                'hidden': 1,
#                'last_name': 'Веселова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 369,
#                'user_id': 369},
#               {'bdate': '4.7.1985',
#                'domain': 'id373',
#                'first_name': 'Светлана',
#                'hidden': 1,
#                'last_name': 'Порошина',
#                'nickname': 'Николаевна',
#                'sex': 1,
#                'uid': 373,
#                'user_id': 373},
#               {'domain': 'ip',
#                'first_name': 'Игорь',
#                'hidden': 1,
#                'last_name': 'Перекопский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 467,
#                'user_id': 467},
#               {'bdate': '22.12',
#                'domain': 'id469',
#                'first_name': 'Екатерина',
#                'hidden': 1,
#                'last_name': 'Пушкина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 469,
#                'user_id': 469},
#               {'domain': 'internet',
#                'first_name': 'Олег',
#                'hidden': 1,
#                'last_name': 'Гайдуль',
#                'nickname': '',
#                'sex': 2,
#                'uid': 517,
#                'user_id': 517},
#               {'bdate': '5.10.1983',
#                'domain': 'dmitriev',
#                'first_name': 'Георгий',
#                'last_name': 'Дмитриев',
#                'nickname': 'GIVISPAM',
#                'sex': 2,
#                'uid': 701,
#                'user_id': 701},
#               {'bdate': '2.1.1987',
#                'domain': 'rakov',
#                'first_name': 'Георгий',
#                'hidden': 1,
#                'last_name': 'Раков',
#                'nickname': 'Сергеевич',
#                'sex': 2,
#                'uid': 702,
#                'user_id': 702},
#               {'bdate': '13.6.1984',
#                'domain': 'id713',
#                'first_name': 'Ирина',
#                'last_name': 'Ксенофонтова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 713,
#                'user_id': 713},
#               {'bdate': '26.6',
#                'domain': 'rusgini',
#                'first_name': 'Руслан',
#                'hidden': 1,
#                'last_name': 'Гиниятуллин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 799,
#                'user_id': 799},
#               {'bdate': '9.11',
#                'domain': 'dariazenit',
#                'first_name': 'Дашуня',
#                'hidden': 1,
#                'last_name': 'Tkacheva',
#                'nickname': '!ЗЕНИТ!',
#                'sex': 1,
#                'uid': 907,
#                'user_id': 907},
#               {'bdate': '11.2.1989',
#                'domain': 'dara',
#                'first_name': 'Дарья',
#                'hidden': 1,
#                'last_name': 'Дудина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 952,
#                'user_id': 952},
#               {'bdate': '11.10.1979',
#                'domain': 'id980',
#                'first_name': 'Анна',
#                'last_name': 'Прудывус',
#                'nickname': '',
#                'sex': 1,
#                'uid': 980,
#                'user_id': 980},
#               {'bdate': '22.3',
#                'domain': 'id1037',
#                'first_name': 'Рената',
#                'hidden': 1,
#                'last_name': 'Глазунова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 1037,
#                'user_id': 1037},
#               {'bdate': '11.1',
#                'domain': 'nkonstantinova',
#                'first_name': 'Наталья',
#                'last_name': 'Константинова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 1057,
#                'user_id': 1057},
#               {'bdate': '31.10',
#                'domain': 'id1228',
#                'first_name': 'Мария',
#                'last_name': 'Кириллова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 1228,
#                'user_id': 1228},
#               {'bdate': '22.3.1984',
#                'domain': 'kamilik',
#                'first_name': 'Камила',
#                'last_name': 'Гимадутзанова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 1439,
#                'user_id': 1439},
#               {'bdate': '4.4.1983',
#                'domain': 'id1634',
#                'first_name': 'Сергей',
#                'last_name': 'Мартынов',
#                'nickname': 'smart',
#                'sex': 2,
#                'uid': 1634,
#                'user_id': 1634},
#               {'bdate': '27.4',
#                'domain': 'me',
#                'first_name': 'Катя',
#                'last_name': 'Лебедева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 2050,
#                'user_id': 2050},
#               {'bdate': '24.10',
#                'domain': 'mirrorkiss',
#                'first_name': 'Екатерина',
#                'hidden': 1,
#                'last_name': 'Кусакина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 2491,
#                'user_id': 2491},
#               {'bdate': '17.12.1988',
#                'domain': 'akonst',
#                'first_name': 'Саша',
#                'last_name': 'Константинов',
#                'nickname': 'ﭢ',
#                'sex': 2,
#                'uid': 2745,
#                'user_id': 2745},
#               {'bdate': '2.11.1983',
#                'domain': 'grusin',
#                'first_name': 'Глеб',
#                'hidden': 1,
#                'last_name': 'Русин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 2791,
#                'user_id': 2791},
#               {'bdate': '20.6.1984',
#                'domain': 'dievsky',
#                'first_name': 'Алексей',
#                'last_name': 'Диевский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 2807,
#                'user_id': 2807},
#               {'bdate': '10.12',
#                'domain': 'pavel.yakushin',
#                'first_name': 'Павел',
#                'last_name': 'Якушин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 2860,
#                'user_id': 2860},
#               {'bdate': '23.3.1988',
#                'domain': 'antanubis',
#                'first_name': 'Вася',
#                'last_name': 'Бабич',
#                'nickname': 'AntanubiS',
#                'sex': 2,
#                'uid': 2943,
#                'user_id': 2943},
#               {'bdate': '14.8.1983',
#                'domain': 'dmitry.novoseltsev',
#                'first_name': 'Дмитрий',
#                'last_name': 'Новосельцев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 3148,
#                'user_id': 3148},
#               {'bdate': '4.2.1988',
#                'domain': 'zhora',
#                'first_name': 'Георгий',
#                'last_name': 'Лобушкин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 3420,
#                'user_id': 3420},
#               {'domain': 'shirokov',
#                'first_name': 'Илья',
#                'hidden': 1,
#                'last_name': 'Широков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 3458,
#                'user_id': 3458},
#               {'bdate': '2.1',
#                'domain': 'dorokhov',
#                'first_name': 'Вадим',
#                'last_name': 'Дорохов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 3520,
#                'user_id': 3520},
#               {'bdate': '24.11.1988',
#                'domain': 'id3637',
#                'first_name': 'Мария',
#                'hidden': 1,
#                'last_name': 'Васильева',
#                'nickname': 'Марыська/verynaglaya',
#                'sex': 1,
#                'uid': 3637,
#                'user_id': 3637},
#               {'bdate': '30.9.1981',
#                'domain': 'eterevsky',
#                'first_name': 'Олег',
#                'last_name': 'Етеревский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 4016,
#                'user_id': 4016},
#               {'bdate': '20.5',
#                'domain': 'sutener',
#                'first_name': 'Антон',
#                'last_name': 'Голиков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 4231,
#                'user_id': 4231},
#               {'bdate': '25.1.1986',
#                'domain': 'egorio',
#                'first_name': 'Егорио',
#                'last_name': 'Вербицкий',
#                'nickname': ':)',
#                'sex': 2,
#                'uid': 4596,
#                'user_id': 4596},
#               {'bdate': '23.6.1988',
#                'domain': 'id4766',
#                'first_name': 'Алексей',
#                'last_name': 'Добромыслов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 4766,
#                'user_id': 4766},
#               {'domain': 'id4781',
#                'first_name': 'Дарья',
#                'last_name': 'Фарафонова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 4781,
#                'user_id': 4781},
#               {'bdate': '25.4.1988',
#                'domain': 'gruznov',
#                'first_name': 'Michael',
#                'last_name': 'Gruznov',
#                'nickname': '',
#                'sex': 2,
#                'uid': 4923,
#                'user_id': 4923},
#               {'bdate': '18.8',
#                'domain': 'wochensky',
#                'first_name': 'Лука',
#                'last_name': 'Вощенский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 5202,
#                'user_id': 5202},
#               {'bdate': '22.2.1989',
#                'domain': 'burunduk1',
#                'first_name': 'Sergey',
#                'last_name': 'Kopeliovich',
#                'nickname': '',
#                'sex': 2,
#                'uid': 5333,
#                'user_id': 5333},
#               {'bdate': '8.11',
#                'domain': 'localhost',
#                'first_name': 'Роман',
#                'last_name': 'Семенов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 5524,
#                'user_id': 5524},
#               {'domain': 'id5634',
#                'first_name': 'Екатерина',
#                'last_name': 'Белохвостова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 5634,
#                'user_id': 5634},
#               {'bdate': '9.11.1988',
#                'domain': 'id6010',
#                'first_name': 'Rena',
#                'hidden': 1,
#                'last_name': 'Ibragimova',
#                'nickname': '',
#                'sex': 1,
#                'uid': 6010,
#                'user_id': 6010},
#               {'bdate': '20.9.1986',
#                'domain': 'dmitry.antipov',
#                'first_name': 'Дмитрий',
#                'last_name': 'Антипов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 6099,
#                'user_id': 6099},
#               {'bdate': '20.1.1984',
#                'domain': 'lifshits',
#                'first_name': 'Юрий',
#                'last_name': 'Лифшиц',
#                'nickname': '',
#                'sex': 2,
#                'uid': 6413,
#                'user_id': 6413},
#               {'bdate': '11.11.1987',
#                'domain': 'andrew',
#                'first_name': 'Андрей',
#                'last_name': 'Рогозов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 6492,
#                'user_id': 6492},
#               {'bdate': '27.7.1983',
#                'domain': 'id6921',
#                'first_name': 'Мария',
#                'last_name': 'Сержантова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 6921,
#                'user_id': 6921},
#               {'bdate': '25.10.1986',
#                'domain': 'oleganza',
#                'first_name': 'Олег',
#                'last_name': 'Андреев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 7146,
#                'user_id': 7146},
#               {'bdate': '26.6.1987',
#                'domain': 'maria.lentsman',
#                'first_name': 'Мария',
#                'hidden': 1,
#                'last_name': 'Ленцман',
#                'nickname': '',
#                'sex': 1,
#                'uid': 7176,
#                'user_id': 7176},
#               {'bdate': '5.12',
#                'domain': 'd_d_o',
#                'first_name': 'Диана',
#                'last_name': 'Овчинникова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 7830,
#                'user_id': 7830},
#               {'bdate': '8.11.1988',
#                'domain': 'shmakov',
#                'first_name': 'Кирилл',
#                'last_name': 'Шмаков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 7990,
#                'user_id': 7990},
#               {'bdate': '4.11.1987',
#                'domain': 'emarkov',
#                'first_name': 'Эльдар',
#                'last_name': 'Марков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 8512,
#                'user_id': 8512},
#               {'bdate': '24.5',
#                'domain': 'id9021',
#                'first_name': 'Иван',
#                'hidden': 1,
#                'last_name': 'Лукашов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 9021,
#                'user_id': 9021},
#               {'bdate': '27.3.1989',
#                'domain': 'dim',
#                'first_name': 'Дмитрий',
#                'last_name': 'Ванюков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 9256,
#                'user_id': 9256},
#               {'domain': 'id10258',
#                'first_name': 'Александр',
#                'hidden': 1,
#                'last_name': 'Кабаков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 10258,
#                'user_id': 10258},
#               {'bdate': '28.8.1988',
#                'domain': 'leeloo_88',
#                'first_name': 'Любовь',
#                'last_name': 'Образцова',
#                'nickname': 'Leeloo',
#                'sex': 1,
#                'uid': 10697,
#                'user_id': 10697},
#               {'bdate': '8.1.1982',
#                'domain': 'alexminza',
#                'first_name': 'Александр',
#                'last_name': 'Мынза',
#                'nickname': '',
#                'sex': 2,
#                'uid': 10741,
#                'user_id': 10741},
#               {'bdate': '30.5.1987',
#                'domain': 'tatianka',
#                'first_name': 'Татьяна',
#                'hidden': 1,
#                'last_name': 'Березовская',
#                'nickname': '',
#                'sex': 1,
#                'uid': 10956,
#                'user_id': 10956},
#               {'bdate': '8.3.1981',
#                'domain': 'kotehok',
#                'first_name': 'Андрей',
#                'last_name': 'Лопатин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 11191,
#                'user_id': 11191},
#               {'bdate': '3.4.1986',
#                'domain': 'egor',
#                'first_name': 'Егор',
#                'last_name': 'Артёменко',
#                'nickname': '',
#                'sex': 2,
#                'uid': 12353,
#                'user_id': 12353},
#               {'bdate': '12.9',
#                'domain': 'izhukov',
#                'first_name': 'Игорь',
#                'last_name': 'Жуков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 13033,
#                'user_id': 13033},
#               {'domain': 'id13319',
#                'first_name': 'Victoria',
#                'hidden': 1,
#                'last_name': 'Akatyeva',
#                'nickname': '',
#                'sex': 1,
#                'uid': 13319,
#                'user_id': 13319},
#               {'bdate': '4.11',
#                'domain': 'evkudryavtseva',
#                'first_name': 'Евгения',
#                'last_name': 'Кудрявцева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 13557,
#                'user_id': 13557},
#               {'bdate': '12.6.1986',
#                'domain': 'ilyasergey',
#                'first_name': 'Илья',
#                'hidden': 1,
#                'last_name': 'Сергей',
#                'nickname': '',
#                'sex': 2,
#                'uid': 13780,
#                'user_id': 13780},
#               {'bdate': '7.4.1986',
#                'domain': 'valtman',
#                'first_name': 'Виталий',
#                'last_name': 'Вальтман',
#                'nickname': '',
#                'sex': 2,
#                'uid': 14099,
#                'user_id': 14099},
#               {'bdate': '9.6',
#                'domain': 'andreivolodin',
#                'first_name': 'Андрей',
#                'last_name': 'Володин',
#                'nickname': 'ॐ',
#                'sex': 2,
#                'uid': 14162,
#                'user_id': 14162},
#               {'bdate': '1.12.1986',
#                'domain': 'daria',
#                'first_name': 'Дарья',
#                'hidden': 1,
#                'last_name': 'Перекопская',
#                'nickname': '',
#                'sex': 1,
#                'uid': 14185,
#                'user_id': 14185},
#               {'bdate': '18.10',
#                'domain': 'meloni',
#                'first_name': 'Катя',
#                'last_name': 'Жукова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 14461,
#                'user_id': 14461},
#               {'bdate': '19.9.1985',
#                'domain': 'elnara',
#                'first_name': 'Эльнара',
#                'last_name': 'Петрова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 15221,
#                'user_id': 15221},
#               {'bdate': '2.11.1989',
#                'domain': 'dkachmar',
#                'first_name': 'Дмитрий',
#                'last_name': 'Качмар',
#                'nickname': '',
#                'sex': 2,
#                'uid': 15460,
#                'user_id': 15460},
#               {'bdate': '6.7.1987',
#                'domain': 'id15496',
#                'first_name': 'Валентина',
#                'last_name': 'Карабаева',
#                'nickname': 'hentza',
#                'sex': 1,
#                'uid': 15496,
#                'user_id': 15496},
#               {'bdate': '15.1.1984',
#                'domain': 'kostya_b',
#                'first_name': 'Костя',
#                'last_name': 'Бенюмов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 15740,
#                'user_id': 15740},
#               {'bdate': '6.11.1986',
#                'domain': 'phil',
#                'first_name': 'Евгений',
#                'last_name': 'Трифонов',
#                'nickname': '"phil"',
#                'sex': 2,
#                'uid': 16990,
#                'user_id': 16990},
#               {'bdate': '30.10.1989',
#                'domain': 'burunduk3',
#                'first_name': 'Олег',
#                'last_name': 'Давыдов',
#                'nickname': '[burunduk3]',
#                'sex': 2,
#                'uid': 18465,
#                'user_id': 18465},
#               {'domain': 'ivan',
#                'first_name': 'Иван',
#                'hidden': 1,
#                'last_name': 'Гимадеев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 20768,
#                'user_id': 20768},
#               {'bdate': '24.10.1986',
#                'domain': 'philipp',
#                'first_name': 'Филипп',
#                'last_name': 'Концаренко',
#                'nickname': '',
#                'sex': 2,
#                'uid': 21513,
#                'user_id': 21513},
#               {'bdate': '11.7',
#                'domain': 'dinarichards',
#                'first_name': 'Дина',
#                'last_name': 'Ричардс',
#                'nickname': '',
#                'sex': 1,
#                'uid': 21980,
#                'user_id': 21980},
#               {'bdate': '19.2.1984',
#                'domain': 'gassa',
#                'first_name': 'Иван',
#                'last_name': 'Казменко',
#                'nickname': '',
#                'sex': 2,
#                'uid': 22802,
#                'user_id': 22802},
#               {'domain': 'aobogatov',
#                'first_name': 'Алексей',
#                'last_name': 'Богатов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 23363,
#                'user_id': 23363},
#               {'bdate': '20.12',
#                'domain': 'stefanez',
#                'first_name': 'Ян',
#                'hidden': 1,
#                'last_name': 'Штефанец',
#                'nickname': '',
#                'sex': 2,
#                'uid': 24613,
#                'user_id': 24613},
#               {'bdate': '22.12',
#                'domain': 'shukin',
#                'first_name': 'Антон',
#                'hidden': 1,
#                'last_name': 'Щукин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 25568,
#                'user_id': 25568},
#               {'domain': 'sashastepanov',
#                'first_name': 'Александр',
#                'hidden': 1,
#                'last_name': 'Степанов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 26047,
#                'user_id': 26047},
#               {'bdate': '12.6.1987',
#                'domain': 'blue_ice',
#                'first_name': 'Вероника',
#                'last_name': 'Якубович',
#                'nickname': '[V]',
#                'sex': 1,
#                'uid': 26615,
#                'user_id': 26615},
#               {'bdate': '8.12',
#                'domain': 'id28078',
#                'first_name': 'Александр',
#                'hidden': 1,
#                'last_name': 'Железняк',
#                'nickname': '',
#                'sex': 2,
#                'uid': 28078,
#                'user_id': 28078},
#               {'domain': 'id29195',
#                'first_name': 'Alexey',
#                'last_name': 'Gorshkov',
#                'nickname': '',
#                'sex': 2,
#                'uid': 29195,
#                'user_id': 29195},
#               {'bdate': '24.1.1983',
#                'domain': 'id33461',
#                'first_name': 'Всеволод',
#                'last_name': 'Бузинов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 33461,
#                'user_id': 33461},
#               {'bdate': '27.11',
#                'domain': 'natalya',
#                'first_name': 'Наталья',
#                'last_name': 'Сосулина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 33723,
#                'user_id': 33723},
#               {'bdate': '28.7',
#                'domain': 'id34028',
#                'first_name': 'Георгий',
#                'hidden': 1,
#                'last_name': 'Шорнин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 34028,
#                'user_id': 34028},
#               {'bdate': '19.5.1988',
#                'domain': 'andreikharlanov',
#                'first_name': 'Андрей',
#                'last_name': 'Харланов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 35345,
#                'user_id': 35345},
#               {'bdate': '25.7',
#                'domain': 'mariae',
#                'first_name': 'Мария',
#                'hidden': 1,
#                'last_name': 'Евневич',
#                'nickname': '',
#                'sex': 1,
#                'uid': 35890,
#                'user_id': 35890},
#               {'bdate': '5.4',
#                'domain': 'george',
#                'first_name': 'Георгий',
#                'last_name': 'Милютин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 36419,
#                'user_id': 36419},
#               {'bdate': '30.9',
#                'domain': 'kk',
#                'first_name': 'Катерина',
#                'last_name': 'Харькова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 36555,
#                'user_id': 36555},
#               {'domain': 'genrix',
#                'first_name': 'Генрих',
#                'last_name': 'Герцен',
#                'nickname': '☮ ▂ ▃ ▅ ▆ ▇ ☮',
#                'sex': 2,
#                'uid': 37831,
#                'user_id': 37831},
#               {'bdate': '9.3.1989',
#                'domain': 'iuliana_belova',
#                'first_name': 'Юлиана',
#                'last_name': 'Белова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 41005,
#                'user_id': 41005},
#               {'domain': 'aremaria',
#                'first_name': 'Мария',
#                'last_name': 'Арепьева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 43857,
#                'user_id': 43857},
#               {'bdate': '27.3.1989',
#                'domain': 'korneev',
#                'first_name': 'Иван',
#                'last_name': 'Корнеев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 46520,
#                'user_id': 46520},
#               {'bdate': '22.9',
#                'domain': 'yankelevich',
#                'first_name': 'Наташа',
#                'hidden': 1,
#                'last_name': 'Йанкелевич',
#                'nickname': '',
#                'sex': 1,
#                'uid': 49309,
#                'user_id': 49309},
#               {'domain': 'igor',
#                'first_name': 'Игорь',
#                'last_name': 'Дьяконов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 49589,
#                'user_id': 49589},
#               {'bdate': '7.8.1990',
#                'domain': 'local',
#                'first_name': 'Глеб',
#                'hidden': 1,
#                'last_name': 'Шкапский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 50030,
#                'user_id': 50030},
#               {'bdate': '19.4.1984',
#                'domain': 'tochki',
#                'first_name': 'Антон',
#                'hidden': 1,
#                'last_name': 'Моржаков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 52946,
#                'user_id': 52946},
#               {'bdate': '11.2.1988',
#                'domain': 'mashakovaleva',
#                'first_name': 'Маша',
#                'last_name': 'Ковалёва',
#                'nickname': '',
#                'sex': 1,
#                'uid': 54602,
#                'user_id': 54602},
#               {'bdate': '9.8.1989',
#                'domain': 'gm',
#                'first_name': 'Гаянэ',
#                'hidden': 1,
#                'last_name': 'Лемешева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 54678,
#                'user_id': 54678},
#               {'domain': 'dolinskiy',
#                'first_name': 'Алексей',
#                'hidden': 1,
#                'last_name': 'Долинский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 55180,
#                'user_id': 55180},
#               {'domain': 'maripilipenko',
#                'first_name': 'Марина',
#                'hidden': 1,
#                'last_name': 'Пилипенко',
#                'nickname': '',
#                'sex': 1,
#                'uid': 56571,
#                'user_id': 56571},
#               {'bdate': '7.2.1988',
#                'domain': 'max',
#                'first_name': 'Максим',
#                'last_name': 'Бабичев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 59628,
#                'user_id': 59628},
#               {'bdate': '2.3',
#                'domain': 'marinagratch',
#                'first_name': 'Марина',
#                'hidden': 1,
#                'last_name': 'Грач',
#                'nickname': '',
#                'sex': 1,
#                'uid': 61399,
#                'user_id': 61399},
#               {'bdate': '14.10.1984',
#                'domain': 'he',
#                'first_name': 'Александр',
#                'last_name': 'Сычев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 62177,
#                'user_id': 62177},
#               {'domain': 'vkcom',
#                'first_name': 'Александр',
#                'hidden': 1,
#                'last_name': 'Каргин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 64081,
#                'user_id': 64081},
#               {'bdate': '25.8.1987',
#                'domain': 'amima',
#                'first_name': 'Андрей',
#                'last_name': 'Мима',
#                'nickname': '',
#                'sex': 2,
#                'uid': 66559,
#                'user_id': 66559},
#               {'bdate': '31.8.1989',
#                'domain': 'illarionov',
#                'first_name': 'Олег',
#                'hidden': 1,
#                'last_name': 'Илларионов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 66748,
#                'user_id': 66748},
#               {'bdate': '10.8',
#                'domain': 'tsykina',
#                'first_name': 'Анна',
#                'last_name': 'Лапырь',
#                'nickname': '',
#                'sex': 1,
#                'uid': 72068,
#                'user_id': 72068},
#               {'bdate': '11.1',
#                'domain': 'pk',
#                'first_name': 'Петр',
#                'hidden': 1,
#                'last_name': 'Харитонов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 72213,
#                'user_id': 72213},
#               {'domain': 'almazovasasha',
#                'first_name': 'Александра',
#                'last_name': 'Алмазова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 73311,
#                'user_id': 73311},
#               {'bdate': '13.6',
#                'domain': 'id74141',
#                'first_name': 'Maksim',
#                'hidden': 1,
#                'last_name': 'Odnoletkov',
#                'nickname': '',
#                'sex': 2,
#                'uid': 74141,
#                'user_id': 74141},
#               {'bdate': '2.2.1990',
#                'domain': 'yp',
#                'first_name': 'Юрий',
#                'hidden': 1,
#                'last_name': 'Петров',
#                'nickname': '',
#                'sex': 2,
#                'uid': 75103,
#                'user_id': 75103},
#               {'domain': 'koshmina',
#                'first_name': 'Yulia',
#                'last_name': 'Koshmina',
#                'nickname': '',
#                'sex': 1,
#                'uid': 76269,
#                'user_id': 76269},
#               {'bdate': '21.2.1983',
#                'domain': 'dobromelov',
#                'first_name': 'Григорий',
#                'last_name': 'Добромелов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 77361,
#                'user_id': 77361},
#               {'domain': 'id77777',
#                'first_name': 'Антон',
#                'hidden': 1,
#                'last_name': 'Розенберг',
#                'nickname': '',
#                'sex': 2,
#                'uid': 77777,
#                'user_id': 77777},
#               {'bdate': '31.12',
#                'domain': 'olga.balandina',
#                'first_name': 'Olga',
#                'hidden': 1,
#                'last_name': 'Balandina',
#                'nickname': '',
#                'sex': 1,
#                'uid': 79288,
#                'user_id': 79288},
#               {'bdate': '29.7.1991',
#                'domain': 'valich',
#                'first_name': 'Валентин',
#                'last_name': 'Фондаратов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 83813,
#                'user_id': 83813},
#               {'bdate': '11.5',
#                'domain': 'allaud',
#                'first_name': 'Антон',
#                'last_name': 'Плешивцев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 85659,
#                'user_id': 85659},
#               {'bdate': '9.2.1982',
#                'domain': 'id88111',
#                'first_name': 'Анастасия',
#                'last_name': 'Ахметзянова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 88111,
#                'user_id': 88111},
#               {'bdate': '13.6.1989',
#                'domain': 'kuteeva_anastasia',
#                'first_name': 'Анастасия',
#                'last_name': 'Кутеева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 88324,
#                'user_id': 88324},
#               {'bdate': '20.6',
#                'domain': 'alyonkaknopka',
#                'first_name': 'Аленка',
#                'hidden': 1,
#                'last_name': 'Попова',
#                'nickname': 'Кнопка',
#                'sex': 1,
#                'uid': 89705,
#                'user_id': 89705},
#               {'bdate': '2.11.1987',
#                'domain': 'vlad',
#                'first_name': 'Владислав',
#                'hidden': 1,
#                'last_name': 'Цыплухин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 93388,
#                'user_id': 93388},
#               {'bdate': '4.8',
#                'domain': 'id93588',
#                'first_name': 'Евгений',
#                'last_name': 'Калинин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 93588,
#                'user_id': 93588},
#               {'bdate': '15.10.1987',
#                'domain': 'prervana',
#                'first_name': 'Злата',
#                'last_name': 'Николаева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 94627,
#                'user_id': 94627},
#               {'bdate': '21.4.1984',
#                'domain': 'id95602',
#                'first_name': 'Анна',
#                'last_name': 'Бертова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 95602,
#                'user_id': 95602},
#               {'bdate': '17.10.1986',
#                'domain': 'id97287',
#                'first_name': 'Дана',
#                'hidden': 1,
#                'last_name': 'Корнишова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 97287,
#                'user_id': 97287},
#               {'bdate': '28.11',
#                'domain': 'arts',
#                'first_name': 'Екатерина',
#                'hidden': 1,
#                'last_name': 'Bahir',
#                'nickname': '✿',
#                'sex': 1,
#                'uid': 97979,
#                'user_id': 97979},
#               {'bdate': '18.5.1987',
#                'domain': 'michaelkhabarov',
#                'first_name': 'Михаил',
#                'last_name': 'Хабаров',
#                'nickname': '',
#                'sex': 2,
#                'uid': 99756,
#                'user_id': 99756},
#               {'domain': 'artyomignatyev',
#                'first_name': 'Артём',
#                'hidden': 1,
#                'last_name': 'Игнатьев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 99797,
#                'user_id': 99797},
#               {'bdate': '22.7.1985',
# ...
#               {'bdate': '14.3',
#                'domain': 'vikaverbovaya',
#                'first_name': 'Виктория',
#                'hidden': 1,
#                'last_name': 'Вербовая',
#                'nickname': '',
#                'sex': 1,
#                'uid': 94288761,
#                'user_id': 94288761},
#               {'bdate': '25.7.1991',
#                'domain': 'kristinamorel',
#                'first_name': 'Кристина',
#                'last_name': 'Селютина',
#                'nickname': 'Евгеньевна',
#                'sex': 1,
#                'uid': 94494238,
#                'user_id': 94494238},
#               {'domain': 'id97023942',
#                'first_name': 'Илья',
#                'last_name': 'Римчиков',
#                'nickname': '',
#                'sex': 2,
#                'uid': 97023942,
#                'user_id': 97023942},
#               {'bdate': '23.12',
#                'domain': 'bible',
#                'first_name': 'Александр',
#                'last_name': 'Король',
#                'nickname': '',
#                'sex': 2,
#                'uid': 100593970,
#                'user_id': 100593970},
#               {'bdate': '29.6',
#                'domain': 'enadi',
#                'first_name': 'Надежда',
#                'last_name': 'Боровикова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 100597874,
#                'user_id': 100597874},
#               {'deactivated': 'deleted',
#                'domain': 'id103211094',
#                'first_name': 'Андрей',
#                'last_name': 'Загоруйко',
#                'sex': 2,
#                'uid': 103211094,
#                'user_id': 103211094},
#               {'bdate': '28.4',
#                'domain': 'gearcxofficial',
#                'first_name': 'Майлз',
#                'last_name': 'Варнер',
#                'nickname': '',
#                'sex': 2,
#                'uid': 107152322,
#                'user_id': 107152322},
#               {'bdate': '18.6.1990',
#                'domain': 'norakirk',
#                'first_name': 'Nora',
#                'hidden': 1,
#                'last_name': 'Kirkizh',
#                'nickname': '',
#                'sex': 1,
#                'uid': 114382036,
#                'user_id': 114382036},
#               {'bdate': '16.5',
#                'domain': 'polina_sckitina',
#                'first_name': 'Полина',
#                'last_name': 'Шкитина',
#                'nickname': '',
#                'sex': 1,
#                'uid': 116369819,
#                'user_id': 116369819},
#               {'deactivated': 'deleted',
#                'domain': 'id122344662',
#                'first_name': 'Federico',
#                'last_name': 'Imparatta',
#                'sex': 2,
#                'uid': 122344662,
#                'user_id': 122344662},
#               {'domain': 'userpig',
#                'first_name': 'Igor',
#                'last_name': 'Belkin',
#                'nickname': '',
#                'sex': 2,
#                'uid': 125188150,
#                'user_id': 125188150},
#               {'bdate': '16.12',
#                'domain': 'iron_ma',
#                'first_name': 'Marina',
#                'last_name': 'Ainullina',
#                'nickname': '',
#                'sex': 1,
#                'uid': 128113045,
#                'user_id': 128113045},
#               {'bdate': '4.6.1976',
#                'domain': 'navalny',
#                'first_name': 'Алексей',
#                'last_name': 'Навальный',
#                'nickname': '',
#                'sex': 2,
#                'uid': 129244038,
#                'user_id': 129244038},
#               {'bdate': '8.4.1994',
#                'domain': 'tra_lya_lya_alya',
#                'first_name': 'Алина',
#                'last_name': 'Баранова',
#                'nickname': '♥ Олеговна ♥',
#                'sex': 1,
#                'uid': 131683356,
#                'user_id': 131683356},
#               {'bdate': '15.1.1996',
#                'domain': 'jasonblow',
#                'first_name': 'Александр',
#                'last_name': 'Романов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 132570235,
#                'user_id': 132570235},
#               {'domain': 'nikolaev_faces',
#                'first_name': 'Anton',
#                'hidden': 1,
#                'last_name': 'Nikolaev',
#                'nickname': '',
#                'sex': 2,
#                'uid': 137976265,
#                'user_id': 137976265},
#               {'bdate': '13.11.1990',
#                'domain': 'angeusa',
#                'first_name': 'Ange',
#                'last_name': 'Luzzato',
#                'nickname': 'The French :)',
#                'sex': 2,
#                'uid': 138911417,
#                'user_id': 138911417},
#               {'bdate': '5.12.1992',
#                'domain': 'grishka7777',
#                'first_name': 'Саша',
#                'hidden': 1,
#                'last_name': 'Гришин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 139389402,
#                'user_id': 139389402},
#               {'bdate': '2.12',
#                'domain': 'mariia_bazuik',
#                'first_name': 'Мария',
#                'last_name': 'Базюк',
#                'nickname': '',
#                'sex': 1,
#                'uid': 141720263,
#                'user_id': 141720263},
#               {'bdate': '19.6',
#                'domain': 'mikhailbabich',
#                'first_name': 'Михаил',
#                'last_name': 'Бабич',
#                'nickname': '',
#                'sex': 2,
#                'uid': 143762628,
#                'user_id': 143762628},
#               {'bdate': '7.6',
#                'domain': 'officialdjdx',
#                'first_name': 'DJ',
#                'last_name': 'DX',
#                'nickname': '',
#                'sex': 2,
#                'uid': 145864825,
#                'user_id': 145864825},
#               {'domain': 'janrezab',
#                'first_name': 'Jan',
#                'last_name': 'Rezab',
#                'nickname': '',
#                'sex': 2,
#                'uid': 151371569,
#                'user_id': 151371569},
#               {'bdate': '27.1',
#                'domain': 'kv',
#                'first_name': 'Владимир',
#                'last_name': 'Владимиров',
#                'nickname': '',
#                'sex': 2,
#                'uid': 151581682,
#                'user_id': 151581682},
#               {'bdate': '23.2.1991',
#                'domain': 'terrakok',
#                'first_name': 'Костя',
#                'hidden': 1,
#                'last_name': 'Цховребов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 152143061,
#                'user_id': 152143061},
#               {'deactivated': 'deleted',
#                'domain': 'id153356329',
#                'first_name': 'Ксения',
#                'last_name': 'Конева',
#                'sex': 1,
#                'uid': 153356329,
#                'user_id': 153356329},
#               {'domain': 'id159714387',
#                'first_name': 'Александр',
#                'last_name': 'Сотник',
#                'nickname': '',
#                'sex': 2,
#                'uid': 159714387,
#                'user_id': 159714387},
#               {'bdate': '4.3.1975',
#                'domain': 'soulmustgoon',
#                'first_name': 'Денис',
#                'last_name': 'Котов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 161801745,
#                'user_id': 161801745},
#               {'bdate': '4.8.1985',
#                'domain': 'dasha_astafieva_official',
#                'first_name': 'Даша',
#                'last_name': 'Астафьева',
#                'nickname': '',
#                'sex': 1,
#                'uid': 162480049,
#                'user_id': 162480049},
#               {'bdate': '14.3.1986',
#                'domain': 'anastasia_domination',
#                'first_name': 'Анастасия',
#                'last_name': 'Кумейко',
#                'nickname': '',
#                'sex': 1,
#                'uid': 163656220,
#                'user_id': 163656220},
#               {'bdate': '1.3',
#                'domain': 'semenovich_official',
#                'first_name': 'Анна',
#                'last_name': 'Семенович',
#                'nickname': '',
#                'sex': 1,
#                'uid': 164542053,
#                'user_id': 164542053},
#               {'bdate': '7.5.1965',
#                'domain': 'id169033674',
#                'first_name': 'Сергей',
#                'hidden': 1,
#                'last_name': 'Сергей',
#                'nickname': '',
#                'sex': 2,
#                'uid': 169033674,
#                'user_id': 169033674},
#               {'bdate': '14.4.1994',
#                'domain': 'id172572693',
#                'first_name': 'Алексей',
#                'hidden': 1,
#                'last_name': 'Гордеев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 172572693,
#                'user_id': 172572693},
#               {'bdate': '21.1.1987',
#                'domain': 'mustangwanted',
#                'first_name': 'Mustang',
#                'last_name': 'Wanted',
#                'nickname': '',
#                'sex': 2,
#                'uid': 173100036,
#                'user_id': 173100036},
#               {'domain': 'roman.dorohov',
#                'first_name': 'Роман',
#                'last_name': 'Дорохов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 173800143,
#                'user_id': 173800143},
#               {'deactivated': 'banned',
#                'domain': 'id175277028',
#                'first_name': 'Лёвик',
#                'last_name': 'Локтионов',
#                'sex': 2,
#                'uid': 175277028,
#                'user_id': 175277028},
#               {'bdate': '7.2.1973',
#                'domain': 'sapr21',
#                'first_name': 'Юрий',
#                'last_name': 'Сапрыкин',
#                'nickname': '',
#                'sex': 2,
#                'uid': 175467516,
#                'user_id': 175467516},
#               {'bdate': '23.11.1993',
#                'domain': 'mabrouk',
#                'first_name': 'Moez',
#                'last_name': 'Mabrouk',
#                'nickname': '',
#                'sex': 2,
#                'uid': 175508620,
#                'user_id': 175508620},
#               {'domain': 'id176259451',
#                'first_name': 'Pavel',
#                'hidden': 1,
#                'last_name': 'Maurus',
#                'nickname': '',
#                'sex': 2,
#                'uid': 176259451,
#                'user_id': 176259451},
#               {'bdate': '24.7.1994',
#                'domain': 'khalil.bargaoui',
#                'first_name': 'Khalil',
#                'last_name': 'Bargaoui',
#                'nickname': '',
#                'sex': 2,
#                'uid': 177234275,
#                'user_id': 177234275},
#               {'domain': 'id177776766',
#                'first_name': 'Маргарита',
#                'hidden': 1,
#                'last_name': 'Иванова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 177776766,
#                'user_id': 177776766},
#               {'bdate': '25.7.1990',
#                'domain': 'imen902',
#                'first_name': 'Imen',
#                'last_name': 'Abdelghani',
#                'nickname': '',
#                'sex': 1,
#                'uid': 179082346,
#                'user_id': 179082346},
#               {'bdate': '1.4.1988',
#                'domain': 'id182864549',
#                'first_name': 'Олег',
#                'last_name': 'Соболев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 182864549,
#                'user_id': 182864549},
#               {'domain': 'alenavl',
#                'first_name': 'Алена',
#                'last_name': 'Владимирская',
#                'nickname': '',
#                'sex': 1,
#                'uid': 183800139,
#                'user_id': 183800139},
#               {'bdate': '20.4',
#                'domain': 'id184316930',
#                'first_name': 'Nastya',
#                'last_name': 'House',
#                'nickname': '',
#                'sex': 1,
#                'uid': 184316930,
#                'user_id': 184316930},
#               {'domain': 'fix',
#                'first_name': 'Дима',
#                'last_name': 'Фикс',
#                'nickname': '',
#                'sex': 2,
#                'uid': 184500506,
#                'user_id': 184500506},
#               {'bdate': '27.12.1972',
#                'domain': 'vkvirikashvili',
#                'first_name': 'Вячеслав',
#                'last_name': 'Квирикашвили',
#                'nickname': '',
#                'sex': 2,
#                'uid': 195272599,
#                'user_id': 195272599},
#               {'domain': 'tomcruise',
#                'first_name': 'Tom',
#                'last_name': 'Cruise',
#                'nickname': '',
#                'sex': 2,
#                'uid': 205387401,
#                'user_id': 205387401},
#               {'domain': 'id208990679',
#                'first_name': 'Леонид',
#                'last_name': 'Парфенов',
#                'nickname': '',
#                'sex': 2,
#                'uid': 208990679,
#                'user_id': 208990679},
#               {'bdate': '14.3.1988',
#                'domain': 'sashagrey',
#                'first_name': 'Sasha',
#                'last_name': 'Grey',
#                'nickname': '',
#                'sex': 1,
#                'uid': 209991765,
#                'user_id': 209991765},
#               {'domain': 'anniegaus',
#                'first_name': 'Annie',
#                'last_name': 'Gaus',
#                'nickname': '',
#                'sex': 1,
#                'uid': 212404674,
#                'user_id': 212404674},
#               {'domain': 'alexander.vassiliev',
#                'first_name': 'Alexander',
#                'hidden': 1,
#                'last_name': 'Vassiliev',
#                'nickname': '',
#                'sex': 2,
#                'uid': 221786295,
#                'user_id': 221786295},
#               {'bdate': '5.7',
#                'domain': 'erikaherceg',
#                'first_name': 'Эрика',
#                'last_name': 'Герцег',
#                'nickname': '',
#                'sex': 1,
#                'uid': 227058817,
#                'user_id': 227058817},
#               {'bdate': '6.6',
#                'domain': 'xoclate',
#                'first_name': 'Eci',
#                'hidden': 1,
#                'last_name': 'Handayani',
#                'nickname': '',
#                'sex': 1,
#                'uid': 231809085,
#                'user_id': 231809085},
#               {'bdate': '26.6.1975',
#                'domain': 'vk_sergeev_dmitry',
#                'first_name': 'Дмитрий',
#                'last_name': 'Сергеев',
#                'nickname': '',
#                'sex': 2,
#                'uid': 233754083,
#                'user_id': 233754083},
#               {'bdate': '30.10',
#                'domain': 'id234215159',
#                'first_name': 'Меседа',
#                'last_name': 'Багаудинова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 234215159,
#                'user_id': 234215159},
#               {'bdate': '26.6.1963',
#                'domain': 'm.khodorkovsky',
#                'first_name': 'Михаил',
#                'last_name': 'Ходорковский',
#                'nickname': '',
#                'sex': 2,
#                'uid': 241575572,
#                'user_id': 241575572},
#               {'bdate': '7.11.1989',
#                'domain': 'tolokno',
#                'first_name': 'Надежда',
#                'last_name': 'Толоконникова',
#                'nickname': '',
#                'sex': 1,
#                'uid': 244683801,
#                'user_id': 244683801},
#               {'bdate': '24.6.1982',
#                'domain': 'nna',
#                'first_name': 'Николай',
#                'last_name': 'Никифоров',
#                'nickname': '',
#                'sex': 2,
#                'uid': 292653561,
#                'user_id': 292653561}]}

# %% [markdown]
# Normally, JSON decoding will create dicts or lists from the supplied data. If you want
# to create different kinds of objects, supply the `object_pairs_hook` or `object_hook` to
# `json.loads()`. For example, here is how you would decode JSON data, preserving its
# order in an `OrderedDict`:

# %%
s = '{"name": "ACME", "shares": 50, "price": 490.1}'
from collections import OrderedDict
data = json.loads(s, object_pairs_hook=OrderedDict)
data
# Out:
# OrderedDict([('name', 'ACME'), ('shares', 50), ('price', 490.1)])

# %% [markdown]
# Here is how you could turn a JSON dictionary into a Python object:

# %%
class JSONObject:
    def __init__(self, d):
        self.__dict__ = d
data = json.loads(s, object_hook=JSONObject)
data.name
# Out:
# 'ACME'

# %%
data.shares
# Out:
# 50

# %%
data.price
# Out:
# 490.1

# %% [markdown]
# In this last example, the dictionary created by decoding the JSON data is passed as a
# single argument to `__init__()`. From there, you are free to use it as you will, such as
# using it directly as the instance dictionary of the object.
#
# There are a few options that can be useful for encoding JSON. If you would like the
# output to be nicely formatted, you can use the `indent` argument to `json.dumps()`. This
# causes the output to be pretty printed in a format similar to that with the `pprint()`
# function. For example:

# %%
data = json.loads(s)
print(json.dumps(data))
# Out:
# {"name": "ACME", "shares": 50, "price": 490.1}

# %%
print(json.dumps(data, indent=4))
# Out:
# {
#     "name": "ACME",
#     "shares": 50,
#     "price": 490.1
# }

# %% [markdown]
# If you want the keys to be sorted on output, used the `sort_keys` argument:

# %%
print(json.dumps(data, sort_keys=True))
# Out:
# {"name": "ACME", "price": 490.1, "shares": 50}

# %% [markdown]
# Instances are not normally serializable as JSON. For example:

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

# %%
p = Point(2, 3)
json.dumps(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-25195f91d6b7> in <module>()
#       1 p = Point(2, 3)
# ----> 2 json.dumps(p)
#
# /usr/lib/python3.4/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     228         cls is None and indent is None and separators is None and
#     229         default is None and not sort_keys and not kw):
# --> 230         return _default_encoder.encode(obj)
#     231     if cls is None:
#     232         cls = JSONEncoder
#
# /usr/lib/python3.4/json/encoder.py in encode(self, o)
#     190         # exceptions aren't as detailed.  The list call should be roughly
#     191         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 192         chunks = self.iterencode(o, _one_shot=True)
#     193         if not isinstance(chunks, (list, tuple)):
#     194             chunks = list(chunks)
#
# /usr/lib/python3.4/json/encoder.py in iterencode(self, o, _one_shot)
#     248                 self.key_separator, self.item_separator, self.sort_keys,
#     249                 self.skipkeys, _one_shot)
# --> 250         return _iterencode(o, 0)
#     251
#     252 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /usr/lib/python3.4/json/encoder.py in default(self, o)
#     171
#     172         """
# --> 173         raise TypeError(repr(o) + " is not JSON serializable")
#     174
#     175     def encode(self, o):
#
# TypeError: <__main__.Point object at 0x7f7bf8068c88> is not JSON serializable

# %% [markdown]
# If you want to serialize instances, you can supply a function that takes an instance as
# input and returns a dictionary that can be serialized. For example:

# %%
def serialize_instance(obj):
    d = {'__classname__' : type(obj).__name__}
    d.update(vars(obj))
    return d

# %% [markdown]
# If you want to get an instance back, you could write code like this:

# %%
# Dictionary mapping names to known classes
classes = {
    'Point' : Point
}

def unserialize_object(d):
    clsname = d.pop('__classname__', None)
    if clsname:
        cls = classes[clsname]
        obj = cls.__new__(cls)  # Make instance without calling __init__
        for key, value in d.items():
            setattr(obj, key, value)
        return obj
    else:
        return d

# %% [markdown]
# Here is an example of how these functions are used:

# %%
p = Point(2,3)
s = json.dumps(p, default=serialize_instance)
s
# Out:
# '{"y": 3, "__classname__": "Point", "x": 2}'

# %%
a = json.loads(s, object_hook=unserialize_object)
a

# %%
a.x
# Out:
# 2

# %%
a.y
# Out:
# 3

# %% [markdown]
# The `json` module has a variety of other options for controlling the low-level
# interpretation of numbers, special values such as `NaN`, and more. Consult the
# [documentation](http://docs.python.org/3/library/json.html) for further details.
